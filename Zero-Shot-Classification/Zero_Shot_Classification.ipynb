# %% [markdown]
# <a href="https://colab.research.google.com/github/realBagher/NLP-using-Transformers/blob/main/Zero-Shot-Classification/Zero_Shot_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
import numpy as np
import pandas as pd
import seaborn as sn 
import matplotlib.pyplot as plt 
import textwrap 

from sklearn.metrics import roc_auc_score, f1_score , confusion_matrix

# %%
classifier = pipeline('zero-shot-classification',device=0)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
classifier("These chores are about as tedious (and error-prone) as they sound, and they usually distract from your program’s real goals",candidate_labels=['positive','negative'])
# Out:
# {'labels': ['negative', 'positive'],
#  'scores': [0.9810115694999695, 0.01898845098912716],
#  'sequence': 'These chores are about as tedious (and error-prone) as they sound, and they usually distract from your program’s real goals'}

# %%
text = "Mitochondria are membrane-bound cell organelles (mitochondrion, singular) that generate most of the chemical energy needed to power the cell's biochemical reactions. Chemical energy produced by the mitochondria is stored in a small molecule called adenosine triphosphate (ATP)"
classifier(text,candidate_labels=['law','biology','math'])
# Out:
# {'labels': ['biology', 'law', 'math'],
#  'scores': [0.8415230512619019, 0.13477200269699097, 0.023704925552010536],
#  'sequence': "Mitochondria are membrane-bound cell organelles (mitochondrion, singular) that generate most of the chemical energy needed to power the cell's biochemical reactions. Chemical energy produced by the mitochondria is stored in a small molecule called adenosine triphosphate (ATP)"}

# %%
text = "ensor Processing Unit (TPU) is an AI accelerator application-specific integrated circuit (ASIC) developed by Google for neural network machine learning, using Google's own TensorFlow software.[1] Google began using TPUs internally in 2015, and in 2018 made them available for third party use, both as part of its cloud infrastructure and by offering a smaller version of the chip for sale"
classifier(text,candidate_labels=['computer science','coding','artificial intelligence','math'])
# Out:
# {'labels': ['artificial intelligence', 'computer science', 'coding', 'math'],
#  'scores': [0.9228454828262329,
#   0.061524152755737305,
#   0.013502613641321659,
#   0.0021277833729982376],
#  'sequence': "ensor Processing Unit (TPU) is an AI accelerator application-specific integrated circuit (ASIC) developed by Google for neural network machine learning, using Google's own TensorFlow software.[1] Google began using TPUs internally in 2015, and in 2018 made them available for third party use, both as part of its cloud infrastructure and by offering a smaller version of the chip for sale"}
