# %% [markdown]
# <a href="https://colab.research.google.com/github/realBagher/NLP-using-Transformers/blob/main/text-generation/text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Out:
# --2022-08-07 05:21:08--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56286 (55K) [text/plain]
# Saving to: ‘robert_frost.txt’
#
# robert_frost.txt    100%[===================>]  54.97K  --.-KB/s    in 0.007s
#
# 2022-08-07 05:21:08 (7.46 MB/s) - ‘robert_frost.txt’ saved [56286/56286]

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 6.9 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 35.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 67.0 MB/s
# ...
#      |████████████████████████████████| 101 kB 10.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import pipeline, set_seed

import textwrap 
import numpy as np
import matplotlib.pyplot as plt

from pprint import pprint

# %%
# !cat robert_frost.txt
# Out:
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim
# Because it was grassy and wanted wear,
# Though as for that the passing there
# Had worn them really about the same,
#
# And both that morning equally lay
# In leaves no step had trodden black.
# Oh, I kept the first for another day!
# Yet knowing how way leads on to way
# I doubted if I should ever come back.
#
# I shall be telling this with a sigh
# Somewhere ages and ages hence:
# Two roads diverged in a wood, and I,
# I took the one less traveled by,
# And that has made all the difference.
#
# Whose woods these are I think I know.
# His house is in the village, though;
# He will not see me stopping here
# To watch his woods fill up with snow.
#
# My little horse must think it queer
# ...

# %%
lines = [line.rstrip() for line in open('robert_frost.txt')]
lines = [line for line in lines if len(line)>0]

# %%
gen = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
set_seed(1234)

# %%
lines[0]
# Out:
# 'Two roads diverged in a yellow wood,'

# %%
gen(lines[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 50 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# [{'generated_text': "Two roads diverged in a yellow wood, while the road in a white puddle was a complete blue on account of the rain coming in. It had been raining outside for some time, so it hadn't taken long for people on both sides of"}]

# %%
pprint(_)
# Out:
# [{'generated_text': 'Two roads diverged in a yellow wood, while the road in a '
#                     'white puddle was a complete blue on account of the rain '
#                     'coming in. It had been raining outside for some time, so '
#                     "it hadn't taken long for people on both sides of"}]

# %%
pprint(gen(lines[0],max_length=20))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Two roads diverged in a yellow wood, some of the highways '
#                     'carrying cars had lights that lit up'}]

# %%
pprint(gen(lines[0],num_return_sequences=3,max_lenght=20))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 50 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# [{'generated_text': 'Two roads diverged in a yellow wood, two on each side '
#                     'were covered by smoke as well, so at 1:10 am the fire was '
#                     'quickly extinguished.\n'
#                     '\n'
#                     'The two main roadways, the main artery (Crest Road) and '
#                     'Highway'},
#  {'generated_text': 'Two roads diverged in a yellow wood, with the white '
# ...

# %%
def wrap(x):
  return textwrap.fill(x,replace_whitespace=False,fix_sentence_endings=True)

# %%
out = gen(lines[0],max_length=30)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Two roads diverged in a yellow wood, a few yards by road with little
# traffic, a highway that was no longer to become the capital of the

# %%
prev = "Two roads diverged in a yellow wood, a few yards by road with little" +\
"traffic, a highway that was no longer"

# %%
out = gen(prev+'\n'+lines[2],max_length=60)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Two roads diverged in a yellow wood, a few yards by road with
# littletraffic, a highway that was no longer
# And be one traveler, long
# I stood, on this broad expanse of barren land, on this great forest,
# the hills of the plains,
# And no man was

# %%
prompt = "Neural networks with attention have been used with great success" +\
"in natural language processing."

out = gen(prompt,max_length=300)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Neural networks with attention have been used with great successin
# natural language processing.  Thus, although it has not yet been
# demonstrated definitively, this model is an important step in
# addressing the many neural correlates of language comprehension based
# upon the ability to learn and process complex abstractions using a
# variety of cognitive tasks.
#
# In this study we investigate how neural
# nets are formed from neural data concerning information in a neural
# network.  To measure neuronal patterns of interest using a novel type
# of neural net we use several recent empirical studies demonstrating
# that the neural networks formed in vivo are more resilient to
# adversarial stimuli that have large social and non-parametric
# connectivity dimensions than the networks formed in vitro which are in
# vitro dependent and are not dependent on the reinforcement learning
# ...
